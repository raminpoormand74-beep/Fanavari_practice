# %%
user_name = input('enter your name: ')
password = input('enter your password: ')

if user_name == 'admin' and password == '1234':
    print('login ba movagaghiat anjam shod')
else:
    print('password ya username eshtebah ast')
# Out:
# login ba movagaghiat anjam shod
