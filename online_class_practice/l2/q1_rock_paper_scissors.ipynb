# %%
user1 = input('bazikon 1: ')
user2 = input('bazikon 2: ')

ruls = 'sang', 'kaghaz', 'gheychi'

if user1 not in ruls or user2 not in ruls:

    print('faghat sang kaghaz ya gheychi vared konid')

elif user1 == user2:

    print('mosavi')

elif user1 == 'kaghaz' and user2 == 'gheychi':

    print('bazikon 2 barande')

elif user1 == 'sang' and user2 == 'kaghaz':

    print('bazikon 2 barande')

elif user1 == 'sang' and user2 == 'gheychi':

    print('bazikon 1 barande')

elif user1 == 'gheychi' and user2 == 'kaghaz':

    print('bazikon 1 barande')

elif user1 == 'kaghaz' and user2 == 'sang':

    print('bazikon 1 barande')

elif user1 == 'gheychi' and user2 == 'sang':

    print('bazikon 2 barande')
# Out:
# bazikon 1 barande
