# %%
sabade_kharid_berizad = []
for i in range(5):
    name_product = input('enter your product name: ')

    if len(name_product) < 6:
        sabade_kharid_berizad.append(name_product)

print(sabade_kharid_berizad)
# Out:
# ['zara', 'nike', 'mango', 'alo']
