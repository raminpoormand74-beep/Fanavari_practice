# %%
users=['ali','vahid','mohammadreza','hamidreza','gholamreza','amir','sara','maryam']
count = 0
for i in users:
    if len(i) < 5:
        print(i)
        count += 1
print('tedad afradi ke horoof esmeshon kamtar az 5 hast: ', count)
# Out:
# ali
# amir
# sara
# tedad afradi ke horoof esmeshon kamtar az 5 hast:  3
