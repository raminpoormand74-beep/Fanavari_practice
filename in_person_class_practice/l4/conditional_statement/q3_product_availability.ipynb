# %%
products = ["Laptop", "Mouse", "Keyboard", "Monitor"]
product_name = input("enter your product name from this list 'laptop','mouse','keyboard','monitor'")
product_name = product_name.capitalize()
if product_name in products:
    print('mahsool',product_name , 'dar dastres ast')
else:
    print('mahsool',product_name , 'dar dastres nist')
# Out:
# mahsool Monitor dar dastres ast
