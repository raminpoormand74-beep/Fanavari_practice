# %%
car_speed = int(input('enter your car speed: '))
if car_speed > 120:
    print(car_speed, 'khatarnak')
elif car_speed >=80 and car_speed <=120:
    print(car_speed, 'sorate ziad')
elif car_speed > 0 and car_speed <80:
    print(car_speed, 'sorate normal')
else:
    print(car_speed, 'mashin dar halate istade ast')
# Out:
# 118 sorate ziad
