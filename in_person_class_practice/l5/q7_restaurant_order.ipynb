# %%
foods = ['pizza', 'burger', 'pasta', 'salad']

print(foods)

orders = []

while True:

    food_name = input('esm ghaza ro vared kon: ')

    if food_name == 'order':
        break

    if food_name in foods:
        orders.append(food_name)

print('----- FACTOR -----')

for order in orders:
    print(order)
# Out:
# ['pizza', 'burger', 'pasta', 'salad']
# ----- FACTOR -----
# pizza
# burger
# pasta
# pizza
# salad
