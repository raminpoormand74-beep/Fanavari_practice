# %%
# A ba estefade az list va in
def count_letter(word, character):
    """
    Counts how many times a specific character appears in a word.

    Args:
        word (str): The word to search in.
        character (str): The character to count.

    Returns:
        str: A message containing the character and its number of occurrences.
    """
    char_number = []

    for char in word:
        if char in character:
            char_number.append(char)

    return f"harf mojood dar kalame: {char_number} tedad harf mored nazar dar kalame: {len(char_number)}"

# %%
count_letter('bahram','a')
# Out:
# "harf mojood dar kalame: ['a', 'a'] tedad harf mored nazar dar kalame: 2"

# %%
count_letter('mohammad amin','a')
# Out:
# "harf mojood dar kalame: ['a', 'a', 'a'] tedad harf mored nazar dar kalame: 3"

# %%
# A-1 ba estefade az count
def count_letter(word, character):
    """
    Counts how many times a specific character appears in a word.

    Args:
        word (str): The word to search in.
        character (str): The character to count.

    Returns:
        str: A message showing the number of occurrences.
    """
    count = 0

    for char in word:
        if char == character:
            count += 1

    return f"tedad horof mojood dar kalame: {count}"

# %%
count_letter('bahram','a')
# Out:
# 'tedad horof mojood dar kalame: 2'

# %%
# A-2 ba estefade az list va ==
def count_letter(word, character):
    """
    Counts the occurrences of a specific character in a word.

    Args:
        word (str): The word to search in.
        character (str): The character to count.

    Returns:
        str: A message showing the characters found and their count.
    """
    char_number = []

    for char in word:
        if char == character:
            char_number.append(char)

    return f"harf mojood dar kalame: {char_number} tedad harf mored nazar dar kalame: {len(char_number)}"

# %%
count_letter('alireza','a')
# Out:
# "harf mojood dar kalame: ['a', 'a'] tedad harf mored nazar dar kalame: 2"

# %%
# B bedon estefade az for
def count_letter(word, character):
    """
    Counts how many times a specific character appears in a word.

    Args:
        word (str): The word to search in.
        character (str): The character to count.

    Returns:
        int: The number of occurrences of the character in the word.
    """
    if character in word:
        count = word.count(character)
        return f'tedad harf mojood dar kalame: {count}'

# %%
count_letter('hhhhhamid','h')
# Out:
# 'tedad harf mojood dar kalame: 5'
