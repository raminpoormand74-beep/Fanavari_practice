# %%
# ba ravesh while True
username = 'admin'
password = 1234
count = 0
while True:
    user_name = input('esm khod ra vared kon: ')
    user_password = int(input('password khod ra vared kon'))
    if user_name != username or  user_password != password:
        count += 1
        if count == 3:
            print('account ghofl shode')
            break   
        print('username ya password ghaalt mibashad')
        continue
    else:
        print('ba moafaghiat vared shodid')
        break
# Out:
# username ya password ghaalt mibashad
# username ya password ghaalt mibashad
# account ghofl shode

# %%
# ba ravesh while
username = 'admin'
password = 1234
count = 0
while count < 3:
    user_name = input('esm khod ra vared kon: ')
    user_password = int(input('password khod ra vared kon'))
    if user_name != username or user_password != password :
        print('username ya password ghaalt mibashad')
        count += 1
        continue
    print('ba movafaghiat vared shodid')
    break
else:
    print('account ghofl shod')
# Out:
# username ya password ghaalt mibashad
# username ya password ghaalt mibashad
# username ya password ghaalt mibashad
# account ghofl shod
