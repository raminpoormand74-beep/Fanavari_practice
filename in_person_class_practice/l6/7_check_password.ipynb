# %%
# A
def check_password(password):
    """
    Check whether the password has at least 8 characters
    and contains both letters and digits.

    Parameters:
        password: The password to be checked.

    Returns:
        A message indicating whether the password is valid.
    """

    if len(password) >= 8:

        if not password.isdigit() and not password.isalpha():

            return 'passworde shoma ba movafaghiat sabt shod'

        else:
            return 'passworde shoma ham bayad ham adad dashte bashe ham horof'

    else:
        return 'password zire 8 rgham nabashad'

# %%
check_password('sina')
# Out:
# 'password zire 8 rgham nabashad'

# %%
check_password('sdafsadf')
# Out:
# 'passworde shoma ham bayad ham adad dashte bashe ham horof'

# %%
check_password('ali2ahmad')
# Out:
# 'passworde shoma ba movafaghiat sabt shod'

# %%
# B
def check_password(password):
    """
    Check whether the password has at least 8 characters
    and contains both letters and digits.

    Parameters:
        password: The password to be checked.

    Returns:
        True if the password is valid, otherwise False.
    """

    if len(password) >= 8:

        if not password.isdigit() and not password.isalpha():

            return True

        else:
            return False

    else:
        return False

# %%
check_password('ali')
# Out:
# False

# %%
check_password('alialiali')
# Out:
# False

# %%
check_password('ali2aliali')
# Out:
# True

# %%
# C
def check_password_strength(password):
    """
    Check the strength of a password based on its length,
    letters, digits, and uppercase and lowercase characters.

    Parameters:
        password: The password to be checked.

    Returns:
        1 if the password has fewer than 8 characters.
        2 if the password has at least 8 characters but
          does not contain both letters and digits.
        3 if the password has at least 8 characters and
          contains both letters and digits.
        4 if the password contains letters, digits,
          uppercase and lowercase characters.
    """

    if len(password) < 8:
        return 1

    if not password.isdigit() and not password.isalpha():

        if not password.islower() and not password.isupper():
            return 4

        else:
            return 3

    else:
        return 2

# %%
check_password_strength('ali')
# Out:
# 1

# %%
check_password_strength('alirezasina')
# Out:
# 2

# %%
check_password_strength('ali2rezahooman')
# Out:
# 3

# %%
check_password_strength('ali13Reza')
# Out:
# 4
