# %%
name = ["ramin" , "ali" , "zahra" , "amir" ,]
age = [30 , 25 , 18 , 14]
print(name.append("maryam"))#ye done str be akhar list ezafe mikone
print(name)
print(name.pop())#ye doone az akhar list hazf mikone
name.extend(["sanaz", "mahtab", "mona"])#2 ta list ro baham edgham mikone
print(name)
name.insert(4,"shabnam")#to andis moshakhas str ro ezafe mikone
print(name)
name.remove("ali")#hazf yek onsor moshakhas shode
print(name)
print(name.index("shabnam"))#index kalame ro barmigardoone
print(name.count("mahtab"))#tedad anasor ro mishomare
name.sort()#tartib chinesh ro moratab mikone
print(name)
name.reverse()#tartib chinesh ro bar aks mikone
print(name)
name.clear()#kol list ro pak mikone
print(name)
# Out:
# None
# ['ramin', 'ali', 'zahra', 'amir', 'maryam']
# maryam
# ['ramin', 'ali', 'zahra', 'amir', 'sanaz', 'mahtab', 'mona']
# ['ramin', 'ali', 'zahra', 'amir', 'shabnam', 'sanaz', 'mahtab', 'mona']
# ['ramin', 'zahra', 'amir', 'shabnam', 'sanaz', 'mahtab', 'mona']
# 3
# 1
# ['amir', 'mahtab', 'mona', 'ramin', 'sanaz', 'shabnam', 'zahra']
# ['zahra', 'shabnam', 'sanaz', 'ramin', 'mona', 'mahtab', 'amir']
# []
