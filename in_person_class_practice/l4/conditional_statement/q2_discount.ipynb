# %%
user_price = int(input('enter your price: '))
if user_price > 1000000:
    print('mablagh ghabl az takhfif:',user_price,  '\nmablagh pardakhti shoma bad az 20% takhfif: ', user_price - user_price * 0.20)
elif user_price > 500000 and user_price < 1000000:
    print('mablagh ghabl az takhfif:',user_price,  '\nmablagh pardakhti shoma bad az 15% takhfif: ', user_price - user_price *0.15)
else:
    print('mablagh ghabl az takhfif:',user_price,  '\nmablagh pardakhti shoma bad az 10% takhfif: ', user_price - user_price*0.10)
# Out:
# mablagh ghabl az takhfif: 456987
# mablagh pardakhti shoma bad az 10% takhfif:  411288.3
