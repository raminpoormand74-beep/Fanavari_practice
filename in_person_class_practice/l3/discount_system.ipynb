# %%
"""inja gheymat ro isdigit kardam ta horoof vared nashe va agar horoof vared shod 
msg bede lotfan adad vared konid
va badesh int kardam
va az lower estefade kardam ta be bozorg va kockek boodan hasas nabashe"""
product_name = input('esm mahsooletoon ro vared konid')
price = input('gheymat masool khod ra vared konid')

if price.isdigit():
    product_price = int(price)


    discount_code = 'z14'

    discount = input('code takhfif ra vared konid')
    discount_code_1=discount.lower()

    if discount_code_1 == discount_code :
        discount = product_price * 20 / 100
        final_price = product_price - discount
        print('code takhfif emal shod gheymat nahaie :',final_price,'\n mahsool',product_name,'mobaraketoon bashe')

    else :
        print('code takhfif eshtebah ast')

        discount = input('dobare code takhfif ra vared konid')
        discount_code_1 = discount.lower()

        if discount_code_1 == discount_code :
            discount = product_price *20/100
            final_price = product_price - discount
            print('code takhfif emal shod gheymat nahaie :',final_price,'\n mahsool',product_name,'mobaraketoon bashe')

        else :
            print('code takhfif eshtebah ast')

            discount = input('talash akhar code takhfif ra vared konid')
            discount_code_1 = discount.lower()

            if discount_code_1 == discount_code :
                discount = product_price *20/100
                final_price = product_price - discount
                print('code takhfif emal shod gheymat nahaie :',final_price,'\n mahsool',product_name,'mobaraketoon bashe')

            else :
                print('moteasefane shoma block shodid')
else:
    print('lotfan gheymat mahsool ra be adad vared konid')
# Out:
# lotfan gheymat mahsool ra be adad vared konid
