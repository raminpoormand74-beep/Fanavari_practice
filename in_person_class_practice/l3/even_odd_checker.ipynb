# %%
"""barname tashkhis zoj va fard
inja az isdigit()estefade kardam baraye jologiri az vared kardan horoof
va hamchenin az int estefade kardam ta input ro be integer tabdil kone"""
user = input('adad ra vared konid')
if user.isdigit():
    user_num = int(user)
    if user_num %2 == 0:
        print('-----number',user_num,'is even-----')
    elif user_num %2 != 0:
        print('-----number',user_num,'is odd-----')
else:
    print('-----lotfan adad vared konid-----')
# Out:
# -----number 333 is odd-----
