# %%
students = ['ali','vahid','sara','hamid','reza','elham','mohsen','zahra','paniz','parmida']
scores = [20,17,9,13,7,20,18,3,1,14]
for student, score in zip(students, scores):
    if score>= 10:
        print('ghabool shodegan:', student, score)
# Out:
# ghabool shodegan: ali 20
# ghabool shodegan: vahid 17
# ghabool shodegan: hamid 13
# ghabool shodegan: elham 20
# ghabool shodegan: mohsen 18
# ghabool shodegan: parmida 14

# %%
students = ['ali','vahid','sara','hamid','reza','elham','mohsen','zahra','paniz','parmida']
scores = [20,17,9,13,7,20,18,3,1,14]
for i in range(len(students)):
    if scores[i] >= 10:
        print('ghabool shodegan:',students[i], scores[i])
# Out:
# ghabool shodegan: ali 20
# ghabool shodegan: vahid 17
# ghabool shodegan: hamid 13
# ghabool shodegan: elham 20
# ghabool shodegan: mohsen 18
# ghabool shodegan: parmida 14
