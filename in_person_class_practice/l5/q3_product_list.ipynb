# %%
products = []

while True:
    product_name = input('enter your product name: ')

    if product_name == 'exit':
        break

    products.append(product_name)

print(products)
# Out:
# ['zara', 'adidas', 'nike', 'swatch']
