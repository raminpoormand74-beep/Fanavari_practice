# %%
print('salam')
while True:
    user = input('ye chizi benevis: ')
    if user == 'bye':
        print('good bye')
        break
    print('javab chatbot')
# Out:
# salam
# javab chatbot
# javab chatbot
# javab chatbot
# good bye
