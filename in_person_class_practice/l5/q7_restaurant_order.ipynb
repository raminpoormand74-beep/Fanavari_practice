# %%
foods = ['pizza', 'burger', 'pasta', 'salad']
print(foods)
orders = []
while True:
    user = input('esm ghaza ro vared kon: ')
    if user == 'order':
        break
    if user in foods:
        orders.append(user)
print('----- FACTOR -----')
for i in orders:
    print(i)
# Out:
# ['pizza', 'burger', 'pasta', 'salad']
# ----- FACTOR -----
# pizza
# salad
# burger
# pasta
