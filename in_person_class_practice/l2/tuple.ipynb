# %%
name = ("ramin" , "mohammadreza" , "mohsen")
print(len(name))#tool onsor ha ro mishmare
print(max(name))#bozorg tarin onsor bar asas tartib ro barmigardoone
print(min(name))#kochektarin onsor bar asas tartib ro barmigardoone
print(name.count("ramin"))#tedad ro mide
print(name.index("mohsen"))#index str khaste shode ro barmigardoone
# Out:
# 3
# ramin
# mohammadreza
# 1
# 2
