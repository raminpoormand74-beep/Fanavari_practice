# %%
student_num = (input('nomre ra vared konid'))
if student_num.isdigit():
    score = int(student_num)
    if 0 <= score <= 20:
        if score >=18:
            print('nomre shoma hast',score,'grade shoma hast --- A ---')
        elif 18 > score >=16:
            print('nomre shoma hast',score,'grade shoma hast --- B ---')
        elif 16 > score >= 14:
            print('nomre shoma hast',score,'grade shoma hast --- C ---')
        elif 14 > score >= 10:
            print('nomre shoma hast',score,'grade shoma hast --- D ---')
        elif 10 > score >= 0:
            print('nomre shoma hast',score,'moteasefane --- (faill) --- shodid!!!')

else:
    print('lotfa beyn baze adad bedid')
# Out:
# nomre shoma hast 18 grade shoma hast --- A ---
