# %%
scores = [20,17,9 , 13, 7 , 20 , 18 , 3 , 1 , 14]
for i in range(len(scores)):
    if scores[i] >=10:
        print('ghabool shodegan: ',scores[i])
    else:
        print('mardodi ha: ',scores[i])
# Out:
# ghabool shodegan:  20
# ghabool shodegan:  17
# mardodi ha:  9
# ghabool shodegan:  13
# mardodi ha:  7
# ghabool shodegan:  20
# ghabool shodegan:  18
# mardodi ha:  3
# mardodi ha:  1
# ghabool shodegan:  14
