# %%
#ghesmat string functions
name = "rAmin"
a = "   hello world"
b ="   Hello world   "
c = "hello 12"
print(len(name)) #tool string ro hesab mikone
print(name.upper())#capital kardan string
print(name.lower())#kochek kardan string
print(name.capitalize())#bozorg kardan harf aval string
print(a.title())#aval har kalame ro bozorg mikone
print(a.strip())#hazf fasele aval va akhar matn
print(a.lstrip())#fasele samt chap ro hazf mikone
print(b.rstrip())#fasele samt rast ro hazf mikone
print(name.replace("m","d"))#jaygozini horoof
print(name.find("n"))#shomare index entekhabi ro peyda mikone
print(name[3])
print(a.count("o"))#tedad tekrar ro mishmare
print(a.split())#string ro be list tabdil mikone
print(a.isdigit())#adad bodan ro barresi mikone
# Out:
# 5
# RAMIN
# ramin
# Ramin
#    Hello World
# hello world
# hello world
#    Hello world
# rAdin
# 4
# i
# 2
# ['hello', 'world']
# False
# False
