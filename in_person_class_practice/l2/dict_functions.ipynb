# %%
information = {'name' : 'ramin',
'last name' : 'pourmoradi',
'age' : 30,
'education' : 'mechanical engineer',
'academic degree' : 'master\'s degree', 
'phone' : 912112552 ,
'city' : 'karaj',     
}
print(information['academic degree'])#meghdar value kelid moshakhasi ro mide
print(information['phone'])#meghdar value kelid moshakhasi ro mide
print(information.values())#tamami meghdar hay value ra mide
print(information.keys())#tamami meghdar hay keys ro mide
# Out:
# master's degree
# 912112552
# dict_values(['ramin', 'pourmoradi', 30, 'mechanical engineer', "master's degree", 912112552, 'karaj'])
# dict_keys(['name', 'last name', 'age', 'education', 'academic degree', 'phone', 'city'])
