# %%
"""barname tashkhis mosbat va manfi
inja baraye inke betonam jologiri konam az vared kardan horoof tavasot karbar
az isdigit() estefade kardam 
va chon az isdigit estefade kardam har chizi joz adad vared mikardim error midad
baraye hamin az lstrip("-")estefade kardam yani karbar ghabl az adad be andaze yek index
har chizi joz adad vared kone be jash - mizare"""

adad = input('adad ra vared koni')
if adad.lstrip("-").isdigit():
    number = int(adad)
    if number > 0 :
        print('-----',"number",number,"is posetive",'-----')
    elif number < 0:
        print('-----',"number",number,"is negetive",'-----')
    else :
        print('-----',"number is",number,'-----')
else :
    print('-----','lotfan faghat adad vared konid','-----')
# Out:
# ----- number -185 is negetive -----
